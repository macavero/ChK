# %%
import pandas as pd
import numpy as np

# %%
# Finding cells with error "'NoneType' object has no attribute 'rjust'"
df = pd.read_csv("//allen/programs/celltypes/workgroups/279/Pilot_work/channel_recordings/peak_current_data/channel_data_pipeline_status.csv")
df_copy = df.copy()

mask_notes = df_copy['notes']=="'NoneType' object has no attribute 'rjust'"
cells_error = df_copy[mask_notes]["lims-id_cell_specimen"]
cells_ids_err = [ids for ids in cells_error]

# %%
cells_ids_err
# Out:
# ['H24.51.015.11.54.01.07',
#  'H24.51.015.11.05.01.05',
#  'H24.51.015.11.05.01.06',
#  'Pvalb-IRES-Cre;Ai14-760310.11.10.02',
#  'Pvalb-IRES-Cre;Ai14-760310.11.10.03',
#  'Pvalb-IRES-Cre;Ai14-760310.11.10.04',
#  'Pvalb-IRES-Cre;Ai14-759604.08.04.03',
#  'Pvalb-IRES-Cre;Ai14-759603.09.04.01',
#  'Pvalb-IRES-Cre;Ai14-756513.11.04.01',
#  'Slc17a8-IRES2-Cre-neo;Ai14-757071.01.09.01',
#  'C57BL6J-755441.11.04.01',
#  'C57BL6J-750103.01.11.01',
#  'C57BL6J-750103.01.11.02',
#  'QN24.26.013.14v.03A.02',
#  'C57BL6J-755811.08.11.01',
#  'H24.51.014.11.05.01.07',
#  'H24.03.304.11.55.01.03',
#  'C57BL6J-753121.07.11.03',
#  'H24.03.304.11.51.02.04',
#  'C57BL6J-747778.11.11.02',
#  'C57BL6J-751410.09.11.01',
#  'C57BL6J-751410.09.11.02',
#  'C57BL6J-750093.11.02.02',
#  'C57BL6J-750093.11.02.03',
#  'H24.51.011.11.51.01.05',
#  'H24.51.011.11.51.01.06',
#  'QN24.26.010.14v.03A.03',
#  'H24.06.352.11.54.01.04',
#  'H24.51.010.11.06.01.01',
#  'C57BL6J-742760.05.02.02',
# ...
